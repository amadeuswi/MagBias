# %%
#redundant script!
from magmod import Tb_redbook, Tb_new, Tb_bull
# Out:
# #$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$
# Rescaling the galaxy number density by a factor of 103811.592208 to match the gold sample with 6330073646.61 total galaxies
# #$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$#$

# %%
ztab = np.linspace(0,3);
Tbtab = Tb_redbook(ztab)
Tbnewtab = Tb_new(ztab)
Tbbulltab = Tb_bull(ztab)

# %%
fig = P.figure(); ax = fig.add_subplot(111);
ax.plot(ztab, Tbtab*1e3, ls = ":")
ax.plot(ztab, Tbnewtab)
ax.plot(ztab, Tbbulltab, ls = "--")
